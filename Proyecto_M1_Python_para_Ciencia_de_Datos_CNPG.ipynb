# %% [markdown]
# # **Bootcamp Ciencia de Datos e Inteligencia Artificial**
# # **Proyecto Módulo 1. Python para Ciencia de Datos**

# %% [markdown]
# ## Introducción
#
# Has aprendido lo más elemental en tu camino para convertirte en un científico de datos y estás preparado para afrontar una de las actividades más comunes del trabajo cotidiano de un _data scientist_; es decir, revisar y analizar información solicitada por algún cliente.
#
# Este proyecto representa un desafío que tomará algo de tiempo, de manera que necesitarás mucha concentración y persistencia; sin embargo, eres completamente capaz de resolverlo. Así, en cuestión de semanas notarás la facilidad con que realizas este tipo de actividades.

# %% [markdown]
# ## Demo
#
# Este documento te servirá como inspiración para crear el tuyo: https://drive.google.com/file/d/1HH_aauW-84bnoBcooZtT7hRN4bFT5uB8/view?usp=sharing

# %% [markdown]
# ## ¿Qué construirás?
#
# Un documento de Google Colaboratory que funja como introducción a las actividades más comunes de tu labor cotidiana. Considera que este trabajo se convertirá en una guía para los módulos siguientes, dado que practicarás las habilidades básicas necesarias para implementar un modelo.

# %% [markdown]
# ## Objetivos
#
# El participante:
#
# - Se familiarizará con la estructura del lenguaje **Python** enfocada en la ciencia de datos.
# - Comprenderá que cada proyecto solicitado poseerá distintas características (gráficos de un cierto tipo o diseño, algunos datos estadísticos, entre otros).
# - Entenderá que algunos datos se interpretan mejor al utilizar determinadas herramientas, tales como **Pandas**, **Numpy** y **Matplotlib**.
# - Asimilará la manera de estructurar la información que requiera analizar.

# %% [markdown]
# ## Requisitos
#
# - El proyecto se entregará en forma individual.
# - Cada participante deberá completar el archivo de **Google Colab** ubicado en su **Google Drive** personal. Al finalizar, compartirá el enlace en el espacio designado en **Teams**.

# %% [markdown]
# ## Entregables
#
# Cada participante hará una copia del presente documento y la guardará en su **Google Drive** personal.
#
# Leerá cada una de las preguntas y responderá utilizando bloques de código (a excepción de la pregunta 7, que podrá responderse con un bloque de texto).
#
# Los resultados deberán ser inteligibles y se recomienda utilizar funciones como `print` para dar claridad a las respuestas.
#
# Es posible investigar soluciones en otras fuentes o recurrir a clases anteriores; sin embargo, el estudiante debe comprender lo escrito en código.
#
# Algunas respuestas tienen diversas formas de resolverse, no obstante, debe existir precisión en el código escrito y en el propósito que persigue.
#
# ¡Comencemos!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #No quitar

# %% [markdown]
# ### Pregunta 1
# Descarga los siguientes archivos:
# - Este archivo csv enlista diferentes celulares y una serie de calificaciones de distintos usuarios: https://drive.google.com/file/d/1atasE-fuDyAt8Z7JGZQroKJwjNkbpyrn/view?usp=sharing
# - Este documento csv incluye un listado de las marcas de dichos teléfonos celulares: https://drive.google.com/file/d/1ICBvPkSVajVVMHyrMABYiwuwefv_3oPJ/view?usp=sharing
#
# Sube estos archivos en un **Google Drive** y con `pd.read_csv` nómbralos como `df_modelos` y `df_marcas`.
#
# Indica en un solo código el número de filas que tiene el archivo `df_modelos` que creaste.

# %%
df_modelos = pd.read_csv('/content/Modelos.csv', encoding='latin-1')
df_marcas = pd.read_csv('/content/Marcas.csv', encoding='latin-1')

# %%
len(df_modelos)
# Out:
# 120

# %%
df_modelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Marca         120 non-null    int64
#  1   Modelo           120 non-null    object
#  2   RAM_GB           120 non-null    int64
#  3   ROM_GB           120 non-null    int64
#  4   Calificaciones   120 non-null    int64
#  5   Reseas          120 non-null    int64
#  6   Estrellas        120 non-null    float64
#  7   Precio de lista  120 non-null    int64
#  8   Precio de venta  120 non-null    int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 8.6+ KB

# %% [markdown]
# ### Pregunta 2
# Haz un `merge` de ambos **data frames**, para generar un nuevo **data frame** que incluya los datos de `df_modelos` y `df_marcas`. Tu nuevo **data frame** recibirá el nombre de `df`.
#
# **Pista**: Ambos archivos tienen una columna que los relaciona, llamada `ID Marca`.

# %%
df_marcas = df_marcas.rename(columns= {'ï»¿ID Marca': 'ID Marca'})
df_marcas.head()
# Out:
#    ID Marca Nombre Marca
# 0         1        Apple
# 1         2       I Kall
# 2         3      Infinix
# 3         4         Lava
# 4         5     Motorola

# %%
df = pd.merge( left = df_modelos, right = df_marcas)
df.head()
# Out:
#    ID Marca                                    Modelo  RAM_GB  ROM_GB  \
# 0        10               Redmi 8 (Onyx Black, 64 GB)       4      64
# 1        10            Redmi 8 (Sapphire Blue, 64 GB)       4      32
# 2        10  Redmi Note 8 Pro (Electric Blue, 128 GB)       6      64
# 3        10           Redmi 8A Dual (Sea Blue, 64 GB)       3      64
# 4        10           Redmi 8A Dual (Sea Blue, 32 GB)       2      64
#
#    Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 0          674638    50064        4.4            10999             9999
# 1          674638    50064        4.4            10999             9999
# 2           55815     4614        4.4            17999            16999
# 3             974       71        4.3             9750             9750
# 4            1246       81        4.2             8320             8320
#
#   Nombre Marca
# 0        Redmi
# 1        Redmi
# 2        Redmi
# 3        Redmi
# 4        Redmi

# %% [markdown]
# ### Pregunta 3
# Muestra las primeras cinco filas, las últimas cinco y el nombre de todas las columnas.

# %%
#Primeras 5 filas
df.head()
# Out:
#    ID Marca                                    Modelo  RAM_GB  ROM_GB  \
# 0        10               Redmi 8 (Onyx Black, 64 GB)       4      64
# 1        10            Redmi 8 (Sapphire Blue, 64 GB)       4      32
# 2        10  Redmi Note 8 Pro (Electric Blue, 128 GB)       6      64
# 3        10           Redmi 8A Dual (Sea Blue, 64 GB)       3      64
# 4        10           Redmi 8A Dual (Sea Blue, 32 GB)       2      64
#
#    Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 0          674638    50064        4.4            10999             9999
# 1          674638    50064        4.4            10999             9999
# 2           55815     4614        4.4            17999            16999
# 3             974       71        4.3             9750             9750
# 4            1246       81        4.2             8320             8320
#
#   Nombre Marca
# 0        Redmi
# 1        Redmi
# 2        Redmi
# 3        Redmi
# 4        Redmi

# %%
#Ultimas 5 filas
df.tail()
# Out:
#      ID Marca                                      Modelo  RAM_GB  ROM_GB  \
# 115         6                                Nokia 105 SS       4      64
# 116        11     Tecno Spark Power 2 (Misty Grey, 64 GB)       4       4
# 117        11  Tecno Camon 15 (Fascinating Purple, 64 GB)       4      32
# 118        11          Tecno Camon 15 (SHOAL GOLD, 64 GB)       4      32
# 119         4                                Lava 34 Plus      32      32
#
#      Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 115           75730     7229        4.3             1299             1299
# 116            9603     1157        4.4            11999             9999
# 117            2219      238        4.2            12499            11499
# 118            2219      238        4.2            12499            11499
# 119             361       34        4.1             1699             1699
#
#     Nombre Marca
# 115        Nokia
# 116        Tecno
# 117        Tecno
# 118        Tecno
# 119         Lava

# %%
#Nombre de todas las columnas
list(df.columns)
# Out:
# ['ID Marca',
#  'Modelo',
#  'RAM_GB',
#  'ROM_GB',
#  'Calificaciones',
#  'Rese\x96as',
#  'Estrellas',
#  'Precio de lista',
#  'Precio de venta',
#  'Nombre Marca']

# %% [markdown]
# ### Pregunta 4
# Utiliza los filtros para mostrar todos los teléfonos con 64GB en la columna `ROM_GB` e indica cuántos del listado poseen esta característica.

# %%
filtro = (df['ROM_GB'] == 64)
df[filtro]
# Out:
#      ID Marca                                    Modelo  RAM_GB  ROM_GB  \
# 0          10               Redmi 8 (Onyx Black, 64 GB)       4      64
# 2          10  Redmi Note 8 Pro (Electric Blue, 128 GB)       6      64
# 3          10           Redmi 8A Dual (Sea Blue, 64 GB)       3      64
# 4          10           Redmi 8A Dual (Sea Blue, 32 GB)       2      64
# 5          10          Redmi 8A Dual (Sky White, 32 GB)       2      64
# ..        ...                                       ...     ...     ...
# 109         2                 I Kall K400 (Blue, 64 GB)       4      64
# 111         2                I Kall K1000 (Blue, 64 GB)       4      64
# 113         2                 I Kall K400 (Blue, 64 GB)       4      64
# 114         2                            I Kall K14 New      32      64
# 115         6                              Nokia 105 SS       4      64
#
#      Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 0            674638    50064        4.4            10999             9999
# 2             55815     4614        4.4            17999            16999
# 3               974       71        4.3             9750             9750
# 4              1246       81        4.2             8320             8320
# 5              1246       81        4.2             8499             8249
# ..              ...      ...        ...              ...              ...
# 109             512       47        2.8             7299             7299
# 111             840      111        2.9             7699             7699
# 113             512       47        2.8             7299             7299
# 114            7229      822        3.4              609              609
# 115           75730     7229        4.3             1299             1299
#
#     Nombre Marca
# 0          Redmi
# 2          Redmi
# 3          Redmi
# 4          Redmi
# 5          Redmi
# ..           ...
# 109       I Kall
# 111       I Kall
# 113       I Kall
# 114       I Kall
# 115        Nokia
#
# [62 rows x 10 columns]

# %%
df[filtro].groupby('ROM_GB').count()
# Out:
#         ID Marca  Modelo  RAM_GB  Calificaciones  Reseas  Estrellas  \
# ROM_GB
# 64            62      62      62              62       62         62
#
#         Precio de lista  Precio de venta  Nombre Marca
# ROM_GB
# 64                   62               62            62

# %% [markdown]
# ### Pregunta 5
# Haz un histograma (`hist`) de la columna `ROM_GB` del **data frame** `df`.
#
# El gráfico debe incluir un título y las columnas tener un color personalizado.

# %%
fig, ax = plt.subplots(figsize=(12,4))
x = df['ROM_GB']
ax.hist(x, bins = 22, color = 'purple', edgecolor = 'black')
ax.set_title('Celulares')
ax.set_xlabel('ROM_GB')
ax.set_ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ### Pregunta 6
# Haz un diagrama de dispersión (`scatter`) con las siguientes características: el eje X deberá indicar el contenido de la columna `Precio de lista`, mientras que el eje Y expresará el contenido de la columna `Precio de venta`.
#
# El diagrama debe incluir un título y los puntos tener un color personalizado.

# %%
fig, ax = plt.subplots(figsize=(8,4))
x = df['Precio de lista']
y = df['Precio de venta']
ax.scatter(x, y, color='red')
ax.set_title('Relación entre precio de lista - precio de venta')
ax.set_xlabel('Precio de lista')
ax.set_ylabel('Precio de venta')
plt.show()

# %% [markdown]
# ### Pregunta 7
#
# Con base en el diagrama de la **pregunta 6**, responde la siguiente pregunta: ¿A qué conclusión podrías llegar si observas únicamente la gráfica?

# %% [markdown]
# Marca una relación fuerte entre el precio de lista y precio de venta, ya que, de manera que subre el precio de lista, sube el de venta, marca una tendencia positiva.

# %% [markdown]
# ### Pregunta 8
# Utiliza el código para obtener la siguiente información (ubicada en `df`).
#
# - Promedio de los precios de venta de los modelos marca **Realme**
# - Máximo de estrellas de los modelos marca **Redmi**
# - Mínimo de Estrellas de los modelos marca **Redmi**

# %%
df.head()
# Out:
#    ID Marca                                    Modelo  RAM_GB  ROM_GB  \
# 0        10               Redmi 8 (Onyx Black, 64 GB)       4      64
# 1        10            Redmi 8 (Sapphire Blue, 64 GB)       4      32
# 2        10  Redmi Note 8 Pro (Electric Blue, 128 GB)       6      64
# 3        10           Redmi 8A Dual (Sea Blue, 64 GB)       3      64
# 4        10           Redmi 8A Dual (Sea Blue, 32 GB)       2      64
#
#    Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 0          674638    50064        4.4            10999             9999
# 1          674638    50064        4.4            10999             9999
# 2           55815     4614        4.4            17999            16999
# 3             974       71        4.3             9750             9750
# 4            1246       81        4.2             8320             8320
#
#   Nombre Marca
# 0        Redmi
# 1        Redmi
# 2        Redmi
# 3        Redmi
# 4        Redmi

# %%
filtro2 = (df['Nombre Marca'] == 'Realme')
df[filtro2]
# Out:
#     ID Marca                                   Modelo  RAM_GB  ROM_GB  \
# 10         9          Realme 5i (Forest Green, 64 GB)       4      64
# 11         9             Realme 5i (Aqua Blue, 64 GB)       4      64
# 12         9             Realme 6 (Comet Blue, 64 GB)       6      64
# 13         9           Realme C11 (Rich Green, 32 GB)       2     128
# 14         9            Realme C11 (Rich Grey, 32 GB)       2      32
# 15         9       Realme Narzo 10A (So White, 32 GB)       3      32
# 16         9        Realme Narzo 10A (So Blue, 64 GB)       4      64
# 17         9       Realme Narzo 10A (So White, 64 GB)       4      32
# 18         9        Realme Narzo 10A (So Blue, 32 GB)       3      64
# 19         9            Realme 6 (Comet White, 64 GB)       6      64
# 20         9     Realme 6 Pro (Lightning Blue, 64 GB)       6      16
# 21         9   Realme 6 Pro (Lightning Orange, 64 GB)       6      64
# 22         9    Realme 6 Pro (Lightning Blue, 128 GB)       6     128
# 23         9  Realme 6 Pro (Lightning Orange, 128 GB)       6      64
# 24         9           Realme 6 (Comet White, 128 GB)       6      64
# 25         9     Realme Narzo 10 (That Green, 128 GB)       4     128
# 26         9           Realme 6 (Comet White, 128 GB)       8     128
# 27         9     Realme Narzo 10 (That White, 128 GB)       4      32
# 28         9      Realme Narzo 10 (That Blue, 128 GB)       4     128
# 29         9           Realme C3 (Blazing Red, 32 GB)       3      32
# 30         9           Realme C3 (Frozen Blue, 32 GB)       3      32
# 31         9           Realme C3 (Frozen Blue, 64 GB)       4      64
# 32         9          Realme C2 (Diamond Blue, 32 GB)       2      32
# 33         9         Realme C2 (Diamond Black, 32 GB)       2      32
# 34         9         Realme C2 (Diamond Black, 32 GB)       3      32
# 35         9      Realme C2 (Diamond Sapphire, 32 GB)       3      32
# 36         9          Realme C2 (Diamond Ruby, 32 GB)       3      32
# 37         9          Realme C2 (Diamond Blue, 32 GB)       3      32
# 38         9             Realme 6 (Comet Blue, 64 GB)       4      64
# 39         9            Realme 6 (Comet White, 64 GB)       4      64
# 40         9  Realme 6 Pro (Lightning Orange, 128 GB)       6     128
# 41         9            Realme 6 (Comet Blue, 128 GB)       6     128
# 42         9  Realme 6 Pro (Lightning Orange, 128 GB)       8     128
#
#     Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 10          243106    16497        4.5            10999            10999
# 11          243106    16497        4.5            10999            10999
# 12           30619     3002        4.4            17999            15999
# 13           17476     1209        4.6             8999             7499
# 14           17476     1209        4.6             8999             7499
# 15           42968     2926        4.6             9999             8999
# 16           17313     1129        4.6            10999             9999
# 17           17313     1129        4.6            10999             9999
# 18           42968     2926        4.6             9999             8999
# 19           30619     3002        4.4            17999            15999
# 20           27363     2887        4.5            17999            17999
# 21           27363     2887        4.5            17999            17999
# 22           27363     2887        4.5            18999            18999
# 23           27363     2887        4.5            18999            18999
# 24           30620     3002        4.4            16999            16999
# 25           74661     5759        4.5            12999            11999
# 26           23466     2363        4.4            17999            17999
# 27           74661     5759        4.5            12999            11999
# 28           74661     5759        4.5            12999            11999
# 29           67430     5102        4.5             8999             8999
# 30           67430     5102        4.5             8999             8999
# 31          117862     8088        4.5             9999             9999
# 32          805006    66292        4.4             7999             6999
# 33          805006    66292        4.4             7999             6999
# 34          133935    10009        4.4             8999             7499
# 35          133935    10009        4.4             8999             7499
# 36          133935    10009        4.4             8999             7499
# 37          133935    10009        4.4             8999             7499
# 38           59665     6337        4.4            14999            14999
# 39           59665     6337        4.4            14999            14999
# 40           27365     2887        4.5            18999            18999
# 41           30622     3002        4.4            16999            16999
# 42           14361     1671        4.4            19999            19999
#
#    Nombre Marca
# 10       Realme
# 11       Realme
# 12       Realme
# 13       Realme
# 14       Realme
# 15       Realme
# 16       Realme
# 17       Realme
# 18       Realme
# 19       Realme
# 20       Realme
# 21       Realme
# 22       Realme
# 23       Realme
# 24       Realme
# 25       Realme
# 26       Realme
# 27       Realme
# 28       Realme
# 29       Realme
# 30       Realme
# 31       Realme
# 32       Realme
# 33       Realme
# 34       Realme
# 35       Realme
# 36       Realme
# 37       Realme
# 38       Realme
# 39       Realme
# 40       Realme
# 41       Realme
# 42       Realme

# %%
df[filtro2].groupby('Nombre Marca')['Precio de venta'].mean()
# Out:
# Nombre Marca
# Realme    12423.242424
# Name: Precio de venta, dtype: float64

# %%
filtro3 = (df['Nombre Marca'] == 'Redmi')
df[filtro3]
# Out:
#    ID Marca                                    Modelo  RAM_GB  ROM_GB  \
# 0        10               Redmi 8 (Onyx Black, 64 GB)       4      64
# 1        10            Redmi 8 (Sapphire Blue, 64 GB)       4      32
# 2        10  Redmi Note 8 Pro (Electric Blue, 128 GB)       6      64
# 3        10           Redmi 8A Dual (Sea Blue, 64 GB)       3      64
# 4        10           Redmi 8A Dual (Sea Blue, 32 GB)       2      64
# 5        10          Redmi 8A Dual (Sky White, 32 GB)       2      64
# 6        10     Redmi Note 8 Pro (Halo White, 128 GB)       6      64
# 7        10   Redmi Note 8 Pro (Shadow Black, 128 GB)       6     128
# 8        10   Redmi Note 8 Pro (Shadow Black, 128 GB)       8     128
# 9        10      Redmi 8A Dual (Midnight Grey, 32 GB)       3      32
#
#    Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 0          674638    50064        4.4            10999             9999
# 1          674638    50064        4.4            10999             9999
# 2           55815     4614        4.4            17999            16999
# 3             974       71        4.3             9750             9750
# 4            1246       81        4.2             8320             8320
# 5            1246       81        4.2             8499             8249
# 6           55815     4614        4.4            17999            16999
# 7           55815     4614        4.4            17999            16999
# 8            7137      621        4.4            19999            18999
# 9             974       71        4.3             7999             7790
#
#   Nombre Marca
# 0        Redmi
# 1        Redmi
# 2        Redmi
# 3        Redmi
# 4        Redmi
# 5        Redmi
# 6        Redmi
# 7        Redmi
# 8        Redmi
# 9        Redmi

# %%
df[filtro3].groupby('Nombre Marca')['Estrellas'].max()
# Out:
# Nombre Marca
# Redmi    4.4
# Name: Estrellas, dtype: float64

# %%
df[filtro3].groupby('Nombre Marca')['Estrellas'].min()
# Out:
# Nombre Marca
# Redmi    4.2
# Name: Estrellas, dtype: float64

# %% [markdown]
# ### Pregunta 9
# Utiliza un **Groupby** para mostrar la cantidad de estrellas promedio que cada marca tiene en `df`.

# %%
df.groupby('Nombre Marca') ['Estrellas'].mean()
# Out:
# Nombre Marca
# Apple       4.554545
# I Kall      2.984615
# Infinix     4.387500
# Lava        4.100000
# Motorola    4.400000
# Nokia       4.300000
# Oppo        4.325000
# Poco        4.500000
# Realme      4.475758
# Redmi       4.340000
# Tecno       4.266667
# Vivo        4.375000
# Name: Estrellas, dtype: float64

# %% [markdown]
# ### Pregunta 10
# ¿Qué otro dato puedes obtener de `df` y cómo lo extraerías?

# %%
# Promedio de Precio de lista de la marca Apple

# %%
filtro4 = (df['Nombre Marca'] == 'Apple')
df[filtro4]
# Out:
#     ID Marca                                 Modelo  RAM_GB  ROM_GB  \
# 48         1         Apple iPhone XR (Black, 64 GB)       0      32
# 49         1         Apple iPhone SE (White, 64 GB)       0      64
# 50         1         Apple iPhone SE (Black, 64 GB)       0      32
# 51         1  Apple iPhone XR ((PRODUCT)RED, 64 GB)       0      64
# 52         1           Apple iPhone SE (Red, 64 GB)       0     128
# 53         1        Apple iPhone SE (Black, 128 GB)       0      64
# 54         1          Apple iPhone XR (Blue, 64 GB)       0     128
# 55         1          Apple iPhone XR (Blue, 64 GB)       0      64
# 56         1     Apple iPhone 7 Plus (Black, 32 GB)       0      64
# 57         1        Apple iPhone XR (White, 128 GB)       0      64
# 58         1         Apple iPhone XR (White, 64 GB)       0      64
#
#     Calificaciones  Reseas  Estrellas  Precio de lista  Precio de venta  \
# 48           11572      975        4.6            52500            46999
# 49           12954     1298        4.5            42500            40999
# 50           12954     1298        4.5            42500            40999
# 51           11572      975        4.6            52500            46999
# 52           12954     1298        4.5            42500            40999
# 53           12954     1298        4.5            47800            45999
# 54           11572      975        4.6            52500            46999
# 55           11572      975        4.6            52500            46999
# 56           27442     2853        4.5            37900            34999
# 57           11572      975        4.6            57800            52999
# 58           11572      975        4.6            52500            46999
#
#    Nombre Marca
# 48        Apple
# 49        Apple
# 50        Apple
# 51        Apple
# 52        Apple
# 53        Apple
# 54        Apple
# 55        Apple
# 56        Apple
# 57        Apple
# 58        Apple

# %%
df[filtro4].groupby('Nombre Marca')['Precio de lista'].mean()
# Out:
# Nombre Marca
# Apple    48500.0
# Name: Precio de lista, dtype: float64
